# %% [markdown]
# <b>Betweenness Centrality for Removing Nodes, part 3</b>
#
# This notebook is for reviewing how to find the betweenness centrality for nodes and finding how to remove individual nodes from graphs, and how that affects the set.
#
# Part 2 reviews removing edges versus nodes.

# %%
import csv

import numpy as np
import networkx as nx 
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Select some data to work with for this session

#first create list using all columns
allData = []
with open('one.csv', 'r') as f:
    filereader = csv.reader(f, delimiter="\t", quotechar='"')
    #next(filereader) # skips header row, we don't want to skip since we don't have a header
    for row in filereader:
            allData.append(row)
            
            
#for this practice, lets keep seperate some data by dates and we can compare them!
#All the interactions during the 1840's using a new bit of code
forties = []
edge = []
i=0
for x in allData:
    date=x[2].split("/")
    if len(date)==3:
        if date[2].startswith('4'): #This helps single out decades instead of specific years
        #if date[2]=="49":
            edge.append([x[3],x[4], x[2]])
            forties.append(edge[i])
            i=i+1
            
#fix the solver column by seperating out responders, whitespace, and formatting unknowns
fixedSolver = []
edge = []
i=0

unknown = {"", "Unknown", "unknown"}
for x in forties:
    if ";" in x[1]:
        solvers = x[1].split(";")
        for y in solvers:
            one=x[0].replace(' ', '')
            two=y.replace(' ', '')
            if(one in unknown):
                one="UNKNOWN"
            if(two in unknown):
                two="UNKNOWN"
            fixedSolver.append([one,two])
    else:
        one=x[0].replace(' ', '')
        two=x[1].replace(' ', '')
        if(one in unknown):
            one="UNKNOWN"
        if(two in unknown):
            two="UNKNOWN"
        fixedSolver.append([one,two])
    #i=i+1

# %% [markdown]
# <b>Begin trying to select edges to remove</b>

# %%
#find the edges with the highest centrality
from networkx import edge_betweenness_centrality
import operator
def my_central_edge(G):
    centrality = edge_betweenness_centrality(G)
    sortedCent = sorted(centrality.items(), key=operator.itemgetter(1), reverse=True)
    edge = sortedCent[0]
    print(edge[0])
    return edge[0]

# %%
#make new communities by removing one edge at a time
from networkx import number_connected_components
def make_community(edgeList, iterations):
    
    tempList = list(edgeList)
    graph = nx.from_edgelist(edgeList)
    tempG = nx.from_edgelist(tempList)
    
    communities = number_connected_components(graph)
    compCommunities = number_connected_components(tempG)

    while compCommunities < communities + iterations:
        edge = my_central_edge(tempG)
        for x in tempList:
            if ((x[0] == edge[0]) and (x[1] == edge[1])) or ((x[0] == edge[1]) and (x[1] == edge[0])):
                print(x)
                tempList.remove(x)
                newGraph = nx.from_edgelist(tempList)
                newcentrality = edge_betweenness_centrality(newGraph)
                newsortedCent = sorted(newcentrality.items(), key=operator.itemgetter(1), reverse=True)
                print(newsortedCent)
            tempG = nx.from_edgelist(tempList)
            compCommunities = number_connected_components(tempG)
    return tempList

# %%
#these centralities don't matter, they change each time a community is made
reference = nx.from_edgelist(fixedSolver)
rcentrality = edge_betweenness_centrality(reference)
rsortedCent = sorted(rcentrality.items(), key=operator.itemgetter(1), reverse=True)
rsortedCent
# Out:
# [(('J.W.', 'ThomasWilkinson'), 0.14845679012345678),
#  (('ThomasWilkinson', 'ThomasWilkinson*'), 0.093342151675485),
#  (('T.Morley', 'UNKNOWN'), 0.09237213403880071),
#  (('UNKNOWN', 'J.W.'), 0.08425925925925921),
#  (('UNKNOWN', 'Geometricus'), 0.0725749559082892),
#  (('Geometricus', 'ThomasWilkinson'), 0.06904761904761902),
#  (('UNKNOWN', 'ThomasWilkinson*'), 0.06463844797178128),
#  (('T.J.L.', 'J.W.'), 0.058421516754850085),
#  (('T.Morley', 'Enquirer'), 0.05555555555555555),
#  (('UNKNOWN', 'Gomphos'), 0.05555555555555555),
#  (('UNKNOWN', 'S.A.G.'), 0.05555555555555555),
#  (('UNKNOWN', 'J.M.[ofBiggleswade]*'), 0.05555555555555555),
#  (('J.W.', 'Collegian'), 0.05555555555555555),
#  (('ThomasMorley', 'J.M.[fromPlymouth]*'), 0.05555555555555555),
#  (('ThomasWilkinson', 'Philo-Mathematicus'), 0.05555555555555555),
#  (('ThomasWilkinson', 'Theta'), 0.05555555555555555),
#  (('ThomasWilkinson', 'J.M.[ofBiggleswade]'), 0.05555555555555555),
#  (('ThomasWilkinson', 'J.S.*'), 0.05555555555555555),
#  (('ThomasWilkinson', 'T.Wilkinson*'), 0.05555555555555555),
#  (('ThomasWilkinson', 'SeptimusTebay*'), 0.05555555555555555),
#  (('ThomasWilkinson', 'SeptimusTebay'), 0.05555555555555555),
#  (('J.W.', 'ThomasMorley'), 0.047222222222222235),
#  (('UNKNOWN', 'ThomasMorley'), 0.037037037037037035),
#  (('UNKNOWN', 'J.S.'), 0.036948853615520284),
#  (('ThomasMorley', 'ThomasWilkinson*'), 0.03443562610229276),
#  (('T.Morley', 'T.J.L.'), 0.028880070546737205),
#  (('ThomasMorley', 'J.S.'), 0.018606701940035275),
#  (('AnEsteemedCorrespondent', 'J.Alsop'), 0.013227513227513227),
#  (('AnEsteemedCorrespondent', 'Digamma*'), 0.013227513227513227),
#  (('AnEsteemedCorrespondent', 'ThomasCranstoun*'), 0.013227513227513227),
#  (('AnEsteemedCorrespondent', 'JohnGiblin*'), 0.013227513227513227),
#  (('AnEsteemedCorrespondent', 'J.M.*'), 0.013227513227513227),
#  (('UNKNOWN', 'UNKNOWN'), 0.0),
#  (('Geometricus', 'Geometricus'), 0.0),
#  (('ThomasWilkinson', 'ThomasWilkinson'), 0.0),
#  (('SeptimusTebay', 'SeptimusTebay'), 0.0)]

# %%
#tested 1 iteration, now to up and start testing more
colorList = make_community(fixedSolver, 2)
#colormap is a "generator of sets", contains dictionaries in this case
from networkx import connected_components
colorMap = nx.from_edgelist(colorList)
#add each dictionary to a list so they're easier to pick from
nodes = []
[nodes.append(c) for c in sorted(nx.connected_components(colorMap), key=len, reverse=True)]
#node create a list of lists with nodes in each
#final list will have lists containing nodes in a single component
nodeList = []
i=0;
for x in nodes:
    nodeList.append([])
    for y in x:
        nodeList[i].append(y)
    i+=1
nodeList
# Out:
# ('J.W.', 'ThomasWilkinson')
# ['ThomasWilkinson', 'J.W.']
# ('ThomasWilkinson', 'ThomasWilkinson*')
# ['ThomasWilkinson', 'ThomasWilkinson*']
# ('UNKNOWN', 'Geometricus')
# ['Geometricus', 'UNKNOWN']
# ['Geometricus', 'UNKNOWN']
# ('T.Morley', 'UNKNOWN')
# ['T.Morley', 'UNKNOWN']
# ('T.J.L.', 'J.W.')
# ['T.J.L.', 'J.W.']
# [['J.W.',
#   'J.S.',
#   'Gomphos',
#   'J.M.[ofBiggleswade]*',
#   'ThomasWilkinson*',
#   'J.M.[fromPlymouth]*',
#   'ThomasMorley',
#   'UNKNOWN',
#   'Collegian',
#   'S.A.G.'],
#  ['Geometricus',
#   'Theta',
#   'ThomasWilkinson',
#   'Philo-Mathematicus',
#   'SeptimusTebay',
#   'J.M.[ofBiggleswade]',
#   'J.S.*',
#   'SeptimusTebay*',
#   'T.Wilkinson*'],
#  ['AnEsteemedCorrespondent',
#   'ThomasCranstoun*',
#   'J.M.*',
#   'JohnGiblin*',
#   'J.Alsop',
#   'Digamma*'],
#  ['Enquirer', 'T.J.L.', 'T.Morley']]

# %%
#we have "colorList" and "nodeList" which are the remaining edges and the nodes respectively.
#It would be nice if we could color the edges now!
#There will likely be duplicates, but can figure this out later...
edgeList = []    #to correspond with nodeList 1 to 1 with indices
i = 0
 
for x in nodeList:           #x represents list of nodes in each component
    edgeList.append([])
    for y in x:              #y is an author
        for z in x:          #z is an author
            for c in colorList:
                if (y == c[0] and z == c[1]) or (y == c[1] and z == c[0]):
                    edgeList[i].append(c)
    i+=1
edgeList
# Out:
# [[['ThomasMorley', 'J.W.'],
#   ['UNKNOWN', 'J.W.'],
#   ['J.W.', 'UNKNOWN'],
#   ['Collegian', 'J.W.'],
#   ['ThomasMorley', 'J.S.'],
#   ['UNKNOWN', 'J.S.'],
#   ['UNKNOWN', 'J.S.'],
#   ['Gomphos', 'UNKNOWN'],
#   ['UNKNOWN', 'J.M.[ofBiggleswade]*'],
#   ['UNKNOWN', 'J.M.[ofBiggleswade]*'],
#   ['ThomasMorley', 'ThomasWilkinson*'],
#   ['UNKNOWN', 'ThomasWilkinson*'],
#   ['UNKNOWN', 'ThomasWilkinson*'],
#   ['ThomasMorley', 'J.M.[fromPlymouth]*'],
#   ['ThomasMorley', 'J.W.'],
#   ['ThomasMorley', 'J.S.'],
#   ['ThomasMorley', 'ThomasWilkinson*'],
#   ['ThomasMorley', 'J.M.[fromPlymouth]*'],
#   ['ThomasMorley', 'UNKNOWN'],
#   ['ThomasMorley', 'UNKNOWN'],
#   ['UNKNOWN', 'J.W.'],
#   ['J.W.', 'UNKNOWN'],
#   ['UNKNOWN', 'J.S.'],
#   ['UNKNOWN', 'J.S.'],
#   ['Gomphos', 'UNKNOWN'],
#   ['UNKNOWN', 'J.M.[ofBiggleswade]*'],
#   ['UNKNOWN', 'J.M.[ofBiggleswade]*'],
#   ['UNKNOWN', 'ThomasWilkinson*'],
#   ['UNKNOWN', 'ThomasWilkinson*'],
#   ['ThomasMorley', 'UNKNOWN'],
#   ['ThomasMorley', 'UNKNOWN'],
#   ['UNKNOWN', 'UNKNOWN'],
#   ['S.A.G.', 'UNKNOWN'],
#   ['Collegian', 'J.W.'],
#   ['S.A.G.', 'UNKNOWN']],
#  [['Geometricus', 'Geometricus'],
#   ['Geometricus', 'Geometricus'],
#   ['Geometricus', 'ThomasWilkinson'],
#   ['Geometricus', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['Geometricus', 'ThomasWilkinson'],
#   ['Geometricus', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'ThomasWilkinson'],
#   ['Philo-Mathematicus', 'ThomasWilkinson'],
#   ['SeptimusTebay', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'J.M.[ofBiggleswade]'],
#   ['ThomasWilkinson', 'J.S.*'],
#   ['ThomasWilkinson', 'J.S.*'],
#   ['ThomasWilkinson', 'SeptimusTebay*'],
#   ['ThomasWilkinson', 'T.Wilkinson*'],
#   ['Philo-Mathematicus', 'ThomasWilkinson'],
#   ['SeptimusTebay', 'ThomasWilkinson'],
#   ['SeptimusTebay', 'SeptimusTebay'],
#   ['SeptimusTebay', 'SeptimusTebay'],
#   ['ThomasWilkinson', 'J.M.[ofBiggleswade]'],
#   ['ThomasWilkinson', 'J.S.*'],
#   ['ThomasWilkinson', 'J.S.*'],
#   ['ThomasWilkinson', 'SeptimusTebay*'],
#   ['ThomasWilkinson', 'T.Wilkinson*']],
#  [['AnEsteemedCorrespondent', 'ThomasCranstoun*'],
#   ['AnEsteemedCorrespondent', 'J.M.*'],
#   ['AnEsteemedCorrespondent', 'JohnGiblin*'],
#   ['AnEsteemedCorrespondent', 'J.Alsop'],
#   ['AnEsteemedCorrespondent', 'Digamma*'],
#   ['AnEsteemedCorrespondent', 'ThomasCranstoun*'],
#   ['AnEsteemedCorrespondent', 'J.M.*'],
#   ['AnEsteemedCorrespondent', 'JohnGiblin*'],
#   ['AnEsteemedCorrespondent', 'J.Alsop'],
#   ['AnEsteemedCorrespondent', 'Digamma*']],
#  [['Enquirer', 'T.Morley'],
#   ['T.Morley', 'T.J.L.'],
#   ['Enquirer', 'T.Morley'],
#   ['T.Morley', 'T.J.L.']]]

# %%
#['T.Morley', 'UNKNOWN']
#['T.J.L.', 'J.W.']
#Edges were removed to create green community


#Make a nice graph using nodeList and edgeList to color!!
D = nx.Graph()
D.add_edges_from(fixedSolver)

#width, length
plt.figure(figsize=(20,20))
plt.axis('off')

# generate the layout and place nodes and edges
layout = nx.circular_layout(D, scale=3)

# plot nodes, labels, and edges with options
nx.draw_networkx_nodes(D,pos=layout,
                       nodelist=nodeList[0],
                       node_color='red',
                       node_size=500,
                   alpha=0.8)
nx.draw_networkx_nodes(D,pos=layout,
                       nodelist=nodeList[1],
                       node_color='purple',
                       node_size=500,
                   alpha=0.8)
nx.draw_networkx_nodes(D,pos=layout,
                       nodelist=nodeList[2],
                       node_color='blue',
                       node_size=500,
                   alpha=0.8)
nx.draw_networkx_nodes(D,pos=layout,
                       nodelist=nodeList[3],
                       node_color='green',
                       node_size=500,
                   alpha=0.8)
#add all as dotted to begin with, that way those that were removed will show up as dotted
nx.draw_networkx_edges(D, pos=layout, width=3, style='dotted',
                       edge_color='orange')
nx.draw_networkx_edges(D,pos=layout,
                       edgelist=edgeList[0],
                       width=4,alpha=0.5,edge_color='red')
nx.draw_networkx_edges(D,pos=layout,
                       edgelist=edgeList[1],
                       width=4,alpha=0.5,edge_color='purple')
nx.draw_networkx_edges(D,pos=layout,
                       edgelist=edgeList[2],
                       width=4,alpha=0.5,edge_color='blue')
nx.draw_networkx_edges(D,pos=layout,
                       edgelist=edgeList[3],
                       width=4,alpha=0.5,edge_color='green')
nx.draw_networkx_labels(D, pos=layout, font_size=14)

#plt.show()
plt.savefig("week7betweenness2.png", format="PNG")

# %%
#THIS IS MESSY, but I need to know the order of the centralities after each iteration of edges being removed.
#tested 1 iteration, now to up and start testing more
colorList = make_community(fixedSolver, 3)
#colormap is a "generator of sets", contains dictionaries in this case
from networkx import connected_components
colorMap = nx.from_edgelist(colorList)
#add each dictionary to a list so they're easier to pick from
nodes = []
[nodes.append(c) for c in sorted(nx.connected_components(colorMap), key=len, reverse=True)]
#node create a list of lists with nodes in each
#final list will have lists containing nodes in a single component
nodeList = []
i=0;
for x in nodes:
    nodeList.append([])
    for y in x:
        nodeList[i].append(y)
    i+=1
nodeList
# Out:
# ('J.W.', 'ThomasWilkinson')
# ['ThomasWilkinson', 'J.W.']
# [(('ThomasWilkinson', 'ThomasWilkinson*'), 0.18333333333333332), (('UNKNOWN', 'Geometricus'), 0.12619047619047621), (('UNKNOWN', 'ThomasWilkinson*'), 0.11604938271604939), (('Geometricus', 'ThomasWilkinson'), 0.11560846560846563), (('T.Morley', 'UNKNOWN'), 0.11208112874779542), (('UNKNOWN', 'J.W.'), 0.08209876543209878), (('ThomasMorley', 'ThomasWilkinson*'), 0.07786596119929455), (('T.Morley', 'Enquirer'), 0.05555555555555555), (('UNKNOWN', 'Gomphos'), 0.05555555555555555), (('UNKNOWN', 'S.A.G.'), 0.05555555555555555), (('UNKNOWN', 'J.M.[ofBiggleswade]*'), 0.05555555555555555), (('J.W.', 'Collegian'), 0.05555555555555555), (('ThomasMorley', 'J.M.[fromPlymouth]*'), 0.05555555555555555), (('ThomasWilkinson', 'Philo-Mathematicus'), 0.05555555555555555), (('ThomasWilkinson', 'Theta'), 0.05555555555555555), (('ThomasWilkinson', 'J.M.[ofBiggleswade]'), 0.05555555555555555), (('ThomasWilkinson', 'J.S.*'), 0.05555555555555555), (('ThomasWilkinson', 'T.Wilkinson*'), 0.05555555555555555), (('ThomasWilkinson', 'SeptimusTebay*'), 0.05555555555555555), (('ThomasWilkinson', 'SeptimusTebay'), 0.05555555555555555), (('J.W.', 'ThomasMorley'), 0.04126984126984127), (('T.J.L.', 'J.W.'), 0.038712522045855395), (('UNKNOWN', 'J.S.'), 0.038359788359788365), (('UNKNOWN', 'ThomasMorley'), 0.037037037037037035), (('T.Morley', 'T.J.L.'), 0.02742504409171074), (('ThomasMorley', 'J.S.'), 0.0171957671957672), (('AnEsteemedCorrespondent', 'J.Alsop'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'Digamma*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'ThomasCranstoun*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'JohnGiblin*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'J.M.*'), 0.013227513227513227), (('UNKNOWN', 'UNKNOWN'), 0.0), (('Geometricus', 'Geometricus'), 0.0), (('ThomasWilkinson', 'ThomasWilkinson'), 0.0), (('SeptimusTebay', 'SeptimusTebay'), 0.0)]
# ('ThomasWilkinson', 'ThomasWilkinson*')
# ['ThomasWilkinson', 'ThomasWilkinson*']
# [(('UNKNOWN', 'Geometricus'), 0.30952380952380953), (('Geometricus', 'ThomasWilkinson'), 0.2962962962962963), (('T.Morley', 'UNKNOWN'), 0.1141975308641975), (('UNKNOWN', 'J.W.'), 0.09832451499118167), (('UNKNOWN', 'ThomasMorley'), 0.07936507936507936), (('T.Morley', 'Enquirer'), 0.05555555555555555), (('UNKNOWN', 'Gomphos'), 0.05555555555555555), (('UNKNOWN', 'S.A.G.'), 0.05555555555555555), (('UNKNOWN', 'J.M.[ofBiggleswade]*'), 0.05555555555555555), (('J.W.', 'Collegian'), 0.05555555555555555), (('ThomasMorley', 'J.M.[fromPlymouth]*'), 0.05555555555555555), (('ThomasWilkinson', 'Philo-Mathematicus'), 0.05555555555555555), (('ThomasWilkinson', 'Theta'), 0.05555555555555555), (('ThomasWilkinson', 'J.M.[ofBiggleswade]'), 0.05555555555555555), (('ThomasWilkinson', 'J.S.*'), 0.05555555555555555), (('ThomasWilkinson', 'T.Wilkinson*'), 0.05555555555555555), (('ThomasWilkinson', 'SeptimusTebay*'), 0.05555555555555555), (('ThomasWilkinson', 'SeptimusTebay'), 0.05555555555555555), (('UNKNOWN', 'J.S.'), 0.04541446208112874), (('UNKNOWN', 'ThomasWilkinson*'), 0.04541446208112874), (('T.J.L.', 'J.W.'), 0.03659611992945326), (('T.Morley', 'T.J.L.'), 0.029541446208112866), (('J.W.', 'ThomasMorley'), 0.022927689594356263), (('AnEsteemedCorrespondent', 'J.Alsop'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'Digamma*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'ThomasCranstoun*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'JohnGiblin*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'J.M.*'), 0.013227513227513227), (('ThomasMorley', 'J.S.'), 0.010141093474426807), (('ThomasMorley', 'ThomasWilkinson*'), 0.010141093474426807), (('UNKNOWN', 'UNKNOWN'), 0.0), (('Geometricus', 'Geometricus'), 0.0), (('ThomasWilkinson', 'ThomasWilkinson'), 0.0), (('SeptimusTebay', 'SeptimusTebay'), 0.0)]
# ('UNKNOWN', 'Geometricus')
# ['Geometricus', 'UNKNOWN']
# [(('UNKNOWN', 'Geometricus'), 0.30952380952380953), (('Geometricus', 'ThomasWilkinson'), 0.2962962962962963), (('T.Morley', 'UNKNOWN'), 0.1141975308641975), (('UNKNOWN', 'J.W.'), 0.09832451499118167), (('UNKNOWN', 'ThomasMorley'), 0.07936507936507936), (('T.Morley', 'Enquirer'), 0.05555555555555555), (('UNKNOWN', 'Gomphos'), 0.05555555555555555), (('UNKNOWN', 'S.A.G.'), 0.05555555555555555), (('UNKNOWN', 'J.M.[ofBiggleswade]*'), 0.05555555555555555), (('J.W.', 'Collegian'), 0.05555555555555555), (('ThomasMorley', 'J.M.[fromPlymouth]*'), 0.05555555555555555), (('ThomasWilkinson', 'Philo-Mathematicus'), 0.05555555555555555), (('ThomasWilkinson', 'Theta'), 0.05555555555555555), (('ThomasWilkinson', 'J.M.[ofBiggleswade]'), 0.05555555555555555), (('ThomasWilkinson', 'J.S.*'), 0.05555555555555555), (('ThomasWilkinson', 'T.Wilkinson*'), 0.05555555555555555), (('ThomasWilkinson', 'SeptimusTebay*'), 0.05555555555555555), (('ThomasWilkinson', 'SeptimusTebay'), 0.05555555555555555), (('UNKNOWN', 'J.S.'), 0.045414462081128745), (('UNKNOWN', 'ThomasWilkinson*'), 0.045414462081128745), (('T.J.L.', 'J.W.'), 0.03659611992945326), (('T.Morley', 'T.J.L.'), 0.029541446208112866), (('J.W.', 'ThomasMorley'), 0.022927689594356263), (('AnEsteemedCorrespondent', 'J.Alsop'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'Digamma*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'ThomasCranstoun*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'JohnGiblin*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'J.M.*'), 0.013227513227513227), (('ThomasMorley', 'J.S.'), 0.010141093474426807), (('ThomasMorley', 'ThomasWilkinson*'), 0.010141093474426807), (('UNKNOWN', 'UNKNOWN'), 0.0), (('Geometricus', 'Geometricus'), 0.0), (('ThomasWilkinson', 'ThomasWilkinson'), 0.0), (('SeptimusTebay', 'SeptimusTebay'), 0.0)]
# ['Geometricus', 'UNKNOWN']
# [(('T.Morley', 'UNKNOWN'), 0.054673721340388004), (('UNKNOWN', 'J.W.'), 0.038800705467372125), (('T.Morley', 'Enquirer'), 0.031746031746031744), (('UNKNOWN', 'ThomasMorley'), 0.031746031746031744), (('UNKNOWN', 'Gomphos'), 0.031746031746031744), (('UNKNOWN', 'S.A.G.'), 0.031746031746031744), (('UNKNOWN', 'J.M.[ofBiggleswade]*'), 0.031746031746031744), (('J.W.', 'Collegian'), 0.031746031746031744), (('ThomasMorley', 'J.M.[fromPlymouth]*'), 0.031746031746031744), (('T.J.L.', 'J.W.'), 0.024691358024691357), (('J.W.', 'ThomasMorley'), 0.022927689594356263), (('UNKNOWN', 'J.S.'), 0.021604938271604937), (('UNKNOWN', 'ThomasWilkinson*'), 0.021604938271604937), (('Geometricus', 'ThomasWilkinson'), 0.021164021164021163), (('ThomasWilkinson', 'Philo-Mathematicus'), 0.021164021164021163), (('ThomasWilkinson', 'Theta'), 0.021164021164021163), (('ThomasWilkinson', 'J.M.[ofBiggleswade]'), 0.021164021164021163), (('ThomasWilkinson', 'J.S.*'), 0.021164021164021163), (('ThomasWilkinson', 'T.Wilkinson*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay'), 0.021164021164021163), (('T.Morley', 'T.J.L.'), 0.01763668430335097), (('AnEsteemedCorrespondent', 'J.Alsop'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'Digamma*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'ThomasCranstoun*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'JohnGiblin*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'J.M.*'), 0.013227513227513227), (('ThomasMorley', 'J.S.'), 0.010141093474426807), (('ThomasMorley', 'ThomasWilkinson*'), 0.010141093474426807), (('UNKNOWN', 'UNKNOWN'), 0.0), (('Geometricus', 'Geometricus'), 0.0), (('ThomasWilkinson', 'ThomasWilkinson'), 0.0), (('SeptimusTebay', 'SeptimusTebay'), 0.0)]
# ('T.Morley', 'UNKNOWN')
# ['T.Morley', 'UNKNOWN']
# [(('T.J.L.', 'J.W.'), 0.07936507936507936), (('J.W.', 'UNKNOWN'), 0.06613756613756613), (('T.Morley', 'T.J.L.'), 0.0582010582010582), (('J.W.', 'ThomasMorley'), 0.03968253968253968), (('T.Morley', 'Enquirer'), 0.031746031746031744), (('J.W.', 'Collegian'), 0.031746031746031744), (('ThomasMorley', 'J.M.[fromPlymouth]*'), 0.031746031746031744), (('UNKNOWN', 'Gomphos'), 0.031746031746031744), (('UNKNOWN', 'S.A.G.'), 0.031746031746031744), (('UNKNOWN', 'J.M.[ofBiggleswade]*'), 0.031746031746031744), (('ThomasMorley', 'UNKNOWN'), 0.021164021164021163), (('Geometricus', 'ThomasWilkinson'), 0.021164021164021163), (('ThomasWilkinson', 'Philo-Mathematicus'), 0.021164021164021163), (('ThomasWilkinson', 'Theta'), 0.021164021164021163), (('ThomasWilkinson', 'J.M.[ofBiggleswade]'), 0.021164021164021163), (('ThomasWilkinson', 'J.S.*'), 0.021164021164021163), (('ThomasWilkinson', 'T.Wilkinson*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay'), 0.021164021164021163), (('UNKNOWN', 'J.S.'), 0.018518518518518517), (('UNKNOWN', 'ThomasWilkinson*'), 0.018518518518518517), (('AnEsteemedCorrespondent', 'J.Alsop'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'Digamma*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'ThomasCranstoun*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'JohnGiblin*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'J.M.*'), 0.013227513227513227), (('ThomasMorley', 'J.S.'), 0.013227513227513227), (('ThomasMorley', 'ThomasWilkinson*'), 0.013227513227513227), (('UNKNOWN', 'UNKNOWN'), 0.0), (('Geometricus', 'Geometricus'), 0.0), (('ThomasWilkinson', 'ThomasWilkinson'), 0.0), (('SeptimusTebay', 'SeptimusTebay'), 0.0)]
# ('T.J.L.', 'J.W.')
# ['T.J.L.', 'J.W.']
# [(('J.W.', 'UNKNOWN'), 0.026455026455026454), (('ThomasMorley', 'J.M.[fromPlymouth]*'), 0.023809523809523808), (('J.W.', 'Collegian'), 0.023809523809523808), (('UNKNOWN', 'Gomphos'), 0.023809523809523808), (('UNKNOWN', 'S.A.G.'), 0.023809523809523808), (('UNKNOWN', 'J.M.[ofBiggleswade]*'), 0.023809523809523808), (('ThomasMorley', 'UNKNOWN'), 0.021164021164021163), (('Geometricus', 'ThomasWilkinson'), 0.021164021164021163), (('ThomasWilkinson', 'Philo-Mathematicus'), 0.021164021164021163), (('ThomasWilkinson', 'Theta'), 0.021164021164021163), (('ThomasWilkinson', 'J.M.[ofBiggleswade]'), 0.021164021164021163), (('ThomasWilkinson', 'J.S.*'), 0.021164021164021163), (('ThomasWilkinson', 'T.Wilkinson*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay'), 0.021164021164021163), (('ThomasMorley', 'J.W.'), 0.015873015873015872), (('UNKNOWN', 'J.S.'), 0.01455026455026455), (('UNKNOWN', 'ThomasWilkinson*'), 0.01455026455026455), (('AnEsteemedCorrespondent', 'J.Alsop'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'Digamma*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'ThomasCranstoun*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'JohnGiblin*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'J.M.*'), 0.013227513227513227), (('ThomasMorley', 'J.S.'), 0.009259259259259259), (('ThomasMorley', 'ThomasWilkinson*'), 0.009259259259259259), (('T.Morley', 'T.J.L.'), 0.005291005291005291), (('T.Morley', 'Enquirer'), 0.005291005291005291), (('UNKNOWN', 'UNKNOWN'), 0.0), (('Geometricus', 'Geometricus'), 0.0), (('ThomasWilkinson', 'ThomasWilkinson'), 0.0), (('SeptimusTebay', 'SeptimusTebay'), 0.0)]
# ('J.W.', 'UNKNOWN')
# ['UNKNOWN', 'J.W.']
# [(('J.W.', 'UNKNOWN'), 0.026455026455026454), (('ThomasMorley', 'J.M.[fromPlymouth]*'), 0.023809523809523808), (('J.W.', 'Collegian'), 0.023809523809523808), (('UNKNOWN', 'Gomphos'), 0.023809523809523808), (('UNKNOWN', 'S.A.G.'), 0.023809523809523808), (('UNKNOWN', 'J.M.[ofBiggleswade]*'), 0.023809523809523808), (('ThomasMorley', 'UNKNOWN'), 0.021164021164021163), (('Geometricus', 'ThomasWilkinson'), 0.021164021164021163), (('ThomasWilkinson', 'Philo-Mathematicus'), 0.021164021164021163), (('ThomasWilkinson', 'Theta'), 0.021164021164021163), (('ThomasWilkinson', 'J.M.[ofBiggleswade]'), 0.021164021164021163), (('ThomasWilkinson', 'J.S.*'), 0.021164021164021163), (('ThomasWilkinson', 'T.Wilkinson*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay'), 0.021164021164021163), (('ThomasMorley', 'J.W.'), 0.015873015873015872), (('UNKNOWN', 'J.S.'), 0.01455026455026455), (('UNKNOWN', 'ThomasWilkinson*'), 0.01455026455026455), (('AnEsteemedCorrespondent', 'J.Alsop'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'Digamma*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'ThomasCranstoun*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'JohnGiblin*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'J.M.*'), 0.013227513227513227), (('ThomasMorley', 'J.S.'), 0.009259259259259259), (('ThomasMorley', 'ThomasWilkinson*'), 0.009259259259259259), (('T.Morley', 'T.J.L.'), 0.005291005291005291), (('T.Morley', 'Enquirer'), 0.005291005291005291), (('UNKNOWN', 'UNKNOWN'), 0.0), (('Geometricus', 'Geometricus'), 0.0), (('ThomasWilkinson', 'ThomasWilkinson'), 0.0), (('SeptimusTebay', 'SeptimusTebay'), 0.0)]
# ('J.W.', 'UNKNOWN')
# ['J.W.', 'UNKNOWN']
# [(('ThomasMorley', 'J.W.'), 0.042328042328042326), (('ThomasMorley', 'UNKNOWN'), 0.042328042328042326), (('ThomasMorley', 'J.M.[fromPlymouth]*'), 0.023809523809523808), (('J.W.', 'Collegian'), 0.023809523809523808), (('UNKNOWN', 'Gomphos'), 0.023809523809523808), (('UNKNOWN', 'S.A.G.'), 0.023809523809523808), (('UNKNOWN', 'J.M.[ofBiggleswade]*'), 0.023809523809523808), (('Geometricus', 'ThomasWilkinson'), 0.021164021164021163), (('ThomasWilkinson', 'Philo-Mathematicus'), 0.021164021164021163), (('ThomasWilkinson', 'Theta'), 0.021164021164021163), (('ThomasWilkinson', 'J.M.[ofBiggleswade]'), 0.021164021164021163), (('ThomasWilkinson', 'J.S.*'), 0.021164021164021163), (('ThomasWilkinson', 'T.Wilkinson*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay'), 0.021164021164021163), (('AnEsteemedCorrespondent', 'J.Alsop'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'Digamma*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'ThomasCranstoun*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'JohnGiblin*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'J.M.*'), 0.013227513227513227), (('ThomasMorley', 'J.S.'), 0.011904761904761904), (('ThomasMorley', 'ThomasWilkinson*'), 0.011904761904761904), (('UNKNOWN', 'J.S.'), 0.011904761904761904), (('UNKNOWN', 'ThomasWilkinson*'), 0.011904761904761904), (('T.Morley', 'T.J.L.'), 0.005291005291005291), (('T.Morley', 'Enquirer'), 0.005291005291005291), (('UNKNOWN', 'UNKNOWN'), 0.0), (('Geometricus', 'Geometricus'), 0.0), (('ThomasWilkinson', 'ThomasWilkinson'), 0.0), (('SeptimusTebay', 'SeptimusTebay'), 0.0)]
# ('ThomasMorley', 'J.W.')
# ['ThomasMorley', 'J.W.']
# [(('ThomasMorley', 'UNKNOWN'), 0.021164021164021163), (('Geometricus', 'ThomasWilkinson'), 0.021164021164021163), (('ThomasWilkinson', 'Philo-Mathematicus'), 0.021164021164021163), (('ThomasWilkinson', 'Theta'), 0.021164021164021163), (('ThomasWilkinson', 'J.M.[ofBiggleswade]'), 0.021164021164021163), (('ThomasWilkinson', 'J.S.*'), 0.021164021164021163), (('ThomasWilkinson', 'T.Wilkinson*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay*'), 0.021164021164021163), (('ThomasWilkinson', 'SeptimusTebay'), 0.021164021164021163), (('ThomasMorley', 'J.M.[fromPlymouth]*'), 0.018518518518518517), (('UNKNOWN', 'Gomphos'), 0.018518518518518517), (('UNKNOWN', 'S.A.G.'), 0.018518518518518517), (('UNKNOWN', 'J.M.[ofBiggleswade]*'), 0.018518518518518517), (('AnEsteemedCorrespondent', 'J.Alsop'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'Digamma*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'ThomasCranstoun*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'JohnGiblin*'), 0.013227513227513227), (('AnEsteemedCorrespondent', 'J.M.*'), 0.013227513227513227), (('UNKNOWN', 'J.S.'), 0.011904761904761904), (('UNKNOWN', 'ThomasWilkinson*'), 0.011904761904761904), (('ThomasMorley', 'J.S.'), 0.006613756613756613), (('ThomasMorley', 'ThomasWilkinson*'), 0.006613756613756613), (('T.Morley', 'T.J.L.'), 0.005291005291005291), (('T.Morley', 'Enquirer'), 0.005291005291005291), (('Collegian', 'J.W.'), 0.0026455026455026454), (('UNKNOWN', 'UNKNOWN'), 0.0), (('Geometricus', 'Geometricus'), 0.0), (('ThomasWilkinson', 'ThomasWilkinson'), 0.0), (('SeptimusTebay', 'SeptimusTebay'), 0.0)]
# [['Geometricus',
#   'Theta',
#   'ThomasWilkinson',
#   'Philo-Mathematicus',
#   'SeptimusTebay',
#   'J.M.[ofBiggleswade]',
#   'J.S.*',
#   'SeptimusTebay*',
#   'T.Wilkinson*'],
#  ['J.S.',
#   'Gomphos',
#   'J.M.[ofBiggleswade]*',
#   'ThomasWilkinson*',
#   'J.M.[fromPlymouth]*',
#   'ThomasMorley',
#   'UNKNOWN',
#   'S.A.G.'],
#  ['AnEsteemedCorrespondent',
#   'ThomasCranstoun*',
#   'J.M.*',
#   'JohnGiblin*',
#   'J.Alsop',
#   'Digamma*'],
#  ['Enquirer', 'T.J.L.', 'T.Morley'],
#  ['J.W.', 'Collegian']]

# %%
#we have "colorList" and "nodeList" which are the remaining edges and the nodes respectively.
#It would be nice if we could color the edges now!
#There will likely be duplicates, but can figure this out later...
edgeList = []    #to correspond with nodeList 1 to 1 with indices
i = 0
 
for x in nodeList:           #x represents list of nodes in each component
    edgeList.append([])
    for y in x:              #y is an author
        for z in x:          #z is an author
            for c in colorList:
                if (y == c[0] and z == c[1]) or (y == c[1] and z == c[0]):
                    edgeList[i].append(c)
    i+=1
edgeList
# Out:
# [[['Geometricus', 'Geometricus'],
#   ['Geometricus', 'Geometricus'],
#   ['Geometricus', 'ThomasWilkinson'],
#   ['Geometricus', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['Geometricus', 'ThomasWilkinson'],
#   ['Geometricus', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['Theta', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'ThomasWilkinson'],
#   ['Philo-Mathematicus', 'ThomasWilkinson'],
#   ['SeptimusTebay', 'ThomasWilkinson'],
#   ['ThomasWilkinson', 'J.M.[ofBiggleswade]'],
#   ['ThomasWilkinson', 'J.S.*'],
#   ['ThomasWilkinson', 'J.S.*'],
#   ['ThomasWilkinson', 'SeptimusTebay*'],
#   ['ThomasWilkinson', 'T.Wilkinson*'],
#   ['Philo-Mathematicus', 'ThomasWilkinson'],
#   ['SeptimusTebay', 'ThomasWilkinson'],
#   ['SeptimusTebay', 'SeptimusTebay'],
#   ['SeptimusTebay', 'SeptimusTebay'],
#   ['ThomasWilkinson', 'J.M.[ofBiggleswade]'],
#   ['ThomasWilkinson', 'J.S.*'],
#   ['ThomasWilkinson', 'J.S.*'],
#   ['ThomasWilkinson', 'SeptimusTebay*'],
#   ['ThomasWilkinson', 'T.Wilkinson*']],
#  [['ThomasMorley', 'J.S.'],
#   ['UNKNOWN', 'J.S.'],
#   ['UNKNOWN', 'J.S.'],
#   ['Gomphos', 'UNKNOWN'],
#   ['UNKNOWN', 'J.M.[ofBiggleswade]*'],
#   ['UNKNOWN', 'J.M.[ofBiggleswade]*'],
#   ['ThomasMorley', 'ThomasWilkinson*'],
#   ['UNKNOWN', 'ThomasWilkinson*'],
#   ['UNKNOWN', 'ThomasWilkinson*'],
#   ['ThomasMorley', 'J.M.[fromPlymouth]*'],
#   ['ThomasMorley', 'J.S.'],
#   ['ThomasMorley', 'ThomasWilkinson*'],
#   ['ThomasMorley', 'J.M.[fromPlymouth]*'],
#   ['ThomasMorley', 'UNKNOWN'],
#   ['ThomasMorley', 'UNKNOWN'],
#   ['UNKNOWN', 'J.S.'],
#   ['UNKNOWN', 'J.S.'],
#   ['Gomphos', 'UNKNOWN'],
#   ['UNKNOWN', 'J.M.[ofBiggleswade]*'],
#   ['UNKNOWN', 'J.M.[ofBiggleswade]*'],
#   ['UNKNOWN', 'ThomasWilkinson*'],
#   ['UNKNOWN', 'ThomasWilkinson*'],
#   ['ThomasMorley', 'UNKNOWN'],
#   ['ThomasMorley', 'UNKNOWN'],
#   ['UNKNOWN', 'UNKNOWN'],
#   ['S.A.G.', 'UNKNOWN'],
#   ['S.A.G.', 'UNKNOWN']],
#  [['AnEsteemedCorrespondent', 'ThomasCranstoun*'],
#   ['AnEsteemedCorrespondent', 'J.M.*'],
#   ['AnEsteemedCorrespondent', 'JohnGiblin*'],
#   ['AnEsteemedCorrespondent', 'J.Alsop'],
#   ['AnEsteemedCorrespondent', 'Digamma*'],
#   ['AnEsteemedCorrespondent', 'ThomasCranstoun*'],
#   ['AnEsteemedCorrespondent', 'J.M.*'],
#   ['AnEsteemedCorrespondent', 'JohnGiblin*'],
#   ['AnEsteemedCorrespondent', 'J.Alsop'],
#   ['AnEsteemedCorrespondent', 'Digamma*']],
#  [['Enquirer', 'T.Morley'],
#   ['T.Morley', 'T.J.L.'],
#   ['Enquirer', 'T.Morley'],
#   ['T.Morley', 'T.J.L.']],
#  [['Collegian', 'J.W.'], ['Collegian', 'J.W.']]]
